# %%
import yfinance as yf

# %%
tickerSymbol = 'GOOGL'

# %%
tickerData = yf.Ticker(tickerSymbol)

# %%
tickerdf = tickerData.history(period = '1d')

# %%
tickerdf
# Out:
#                   Open         High          Low        Close   Volume  \
# Date
# 2021-09-13  2838.98999  2858.870117  2825.540039  2846.649902  1061650
#
#             Dividends  Stock Splits
# Date
# 2021-09-13          0             0

# %%
tickerData.info
# Out:
# {'zip': '94043',
#  'sector': 'Communication Services',
#  'fullTimeEmployees': 144056,
#  'longBusinessSummary': 'Alphabet Inc. provides online advertising services in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. The company offers performance and brand advertising services. It operates through Google Services, Google Cloud, and Other Bets segments. The Google Services segment provides products and services, such as ads, Android, Chrome, hardware, Google Maps, Google Play, Search, and YouTube, as well as technical infrastructure; and digital content. The Google Cloud segment offers infrastructure and data analytics platforms, collaboration tools, and other services for enterprise customers. The Other Bets segment sells internet and TV services, as well as licensing and research and development services. The company was founded in 1998 and is headquartered in Mountain View, California.',
#  'city': 'Mountain View',
#  'phone': '650-253-0000',
#  'state': 'CA',
#  'country': 'United States',
#  'companyOfficers': [],
#  'website': 'http://www.abc.xyz',
#  'maxAge': 1,
#  'address1': '1600 Amphitheatre Parkway',
#  'industry': 'Internet Content & Information',
#  'ebitdaMargins': 0.34300998,
#  'profitMargins': 0.2857,
#  'grossMargins': 0.55723,
#  'operatingCashflow': 80858996736,
#  'revenueGrowth': 0.616,
#  'operatingMargins': 0.28448,
#  'ebitda': 75552997376,
#  'targetLowPrice': 1850,
#  'recommendationKey': 'buy',
#  'grossProfits': 97795000000,
#  'freeCashflow': 44609626112,
#  'targetMedianPrice': 3160,
#  'currentPrice': 2846.65,
#  'earningsGrowth': 1.691,
#  'currentRatio': 3.152,
#  'returnOnAssets': 0.12759,
#  'numberOfAnalystOpinions': 43,
#  'targetMeanPrice': 3146.45,
#  'debtToEquity': 11.829,
#  'returnOnEquity': 0.2829,
#  'targetHighPrice': 4288.52,
#  'totalCash': 135863001088,
#  'totalDebt': 28100999168,
#  'totalRevenue': 220265005056,
#  'totalCashPerShare': 203.768,
#  'financialCurrency': 'USD',
#  'revenuePerShare': 326.656,
#  'quickRatio': 3.027,
#  'recommendationMean': 1.7,
#  'exchange': 'NMS',
#  'shortName': 'Alphabet Inc.',
#  'longName': 'Alphabet Inc.',
#  'exchangeTimezoneName': 'America/New_York',
#  'exchangeTimezoneShortName': 'EDT',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '-14400000',
#  'quoteType': 'EQUITY',
#  'symbol': 'GOOGL',
#  'messageBoardId': 'finmb_29096',
#  'market': 'us_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 8.04,
#  'beta3Year': None,
#  'enterpriseToEbitda': 23.438,
#  '52WeekChange': 0.8353745,
#  'morningStarRiskRating': None,
#  'forwardEps': 106.2,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 301084992,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'totalAssets': None,
#  'bookValue': 355.83,
#  'sharesShort': 2994031,
#  'sharesPercentSharesOut': 0.0045,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1609372800,
#  'heldPercentInstitutions': 0.8036,
#  'netIncomeToCommon': 62928998400,
#  'trailingEps': 92.187,
#  'lastDividendValue': None,
#  'SandP52WeekChange': 0.31088436,
#  'priceToBook': 8.000028,
#  'heldPercentInsiders': 0.00148,
#  'nextFiscalYearEnd': 1672444800,
#  'yield': None,
#  'mostRecentQuarter': 1625011200,
#  'shortRatio': 2.85,
#  'sharesShortPreviousMonthDate': 1627603200,
#  'floatShares': 580656843,
#  'beta': 1.004366,
#  'enterpriseValue': 1770833313792,
#  'priceHint': 2,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': None,
#  'lastSplitFactor': None,
#  'legalType': None,
#  'lastDividendDate': None,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': 1.662,
#  'priceToSalesTrailing12Months': 8.647669,
#  'dateShortInterest': 1630368000,
#  'pegRatio': 1.16,
#  'ytdReturn': None,
#  'forwardPE': 26.804613,
#  'lastCapGain': None,
#  'shortPercentOfFloat': 0.01,
#  'sharesShortPriorMonth': 2933691,
#  'impliedSharesOutstanding': 666755008,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'previousClose': 2817.52,
#  'regularMarketOpen': 2838.99,
#  'twoHundredDayAverage': 2417.9119,
#  'trailingAnnualDividendYield': None,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 2858.87,
#  'navPrice': None,
#  'averageDailyVolume10Day': 1132450,
#  'regularMarketPreviousClose': 2817.52,
#  'fiftyDayAverage': 2777.2517,
#  'trailingAnnualDividendRate': None,
#  'open': 2838.99,
#  'toCurrency': None,
#  'averageVolume10days': 1132450,
#  'expireDate': None,
#  'algorithm': None,
#  'dividendRate': None,
#  'exDividendDate': None,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 2825.54,
#  'currency': 'USD',
#  'trailingPE': 30.879084,
#  'regularMarketVolume': 1061650,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 1904778805248,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 1254095,
#  'dayLow': 2825.54,
#  'ask': 0,
#  'askSize': 3200,
#  'volume': 1061650,
#  'fiftyTwoWeekHigh': 2925.08,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 1402.15,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': None,
#  'bidSize': 1000,
#  'dayHigh': 2858.87,
#  'regularMarketPrice': 2846.65,
#  'logo_url': 'https://logo.clearbit.com/abc.xyz'}

# %%
tickerData.calendar
# Out:
#                                     0                    1
# Earnings Date     2021-10-27 20:00:00  2021-11-01 20:00:00
# Earnings Average                 23.4                 23.4
# Earnings Low                     19.5                 19.5
# Earnings High                   30.67                30.67
# Revenue Average           63259500000          63259500000
# Revenue Low               56500000000          56500000000
# Revenue High              67870000000          67870000000

# %%
tickerData.recommendations
# Out:
#                                   Firm    To Grade From Grade Action
# Date
# 2014-12-17 00:00:00   Pivotal Research         Buy                up
# 2015-01-08 06:03:07             Stifel        Hold        Buy   down
# 2015-01-14 09:00:00      Credit Suisse  Outperform              main
# 2015-01-30 09:00:00          Citigroup         Buy              main
# 2015-03-02 14:04:06    Bank of America         Buy    Neutral     up
# ...                                ...         ...        ...    ...
# 2021-07-28 14:32:13             Mizuho         Buy              main
# 2021-07-28 15:07:32          Jefferies         Buy              main
# 2021-07-28 15:11:25          JP Morgan  Overweight              main
# 2021-07-28 15:16:27  Canaccord Genuity         Buy              main
# 2021-09-13 10:22:29      Goldman Sachs         Buy              init
#
# [248 rows x 4 columns]
